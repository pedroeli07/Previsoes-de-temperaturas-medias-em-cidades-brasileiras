# %% [markdown]
# <a href="https://colab.research.google.com/github/pedroeli07/Previsoes-de-temperaturas-medias-em-cidades-brasileiras/blob/main/Previsao_temp_media03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import google.colab.files
# Carregue o arquivo
uploaded_file = google.colab.files.upload()
# Out:
#      <input type="file" id="files-af4bc0b4-fb7e-4997-b942-5534252a8554" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-af4bc0b4-fb7e-4997-b942-5534252a8554">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import rarfile

# Descompacte o arquivo RAR
with rarfile.RarFile("ggg.rar") as rar:
    rar.extractall(".")

# Leia o arquivo CSV descompactado
data = pd.read_csv("GlobalLandTemperaturesByCity.csv")

# %%
# Importe a biblioteca google.colab.drive
import google.colab.drive

# Monte o Google Drive
google.colab.drive.mount('/content/drive')

# Salve o arquivo no Google Drive
with open('GlobalLandTemperaturesByCity.csv', 'r') as f:
    data = f.read()

with open('/content/drive/My Drive/GlobalLandTemperaturesByCity.csv', 'w') as f:
    f.write(data)

# %%
path = "/content/drive/My Drive/GlobalLandTemperaturesByCity.csv"
data = pd.read_csv(path)

# %%
# Obtenha o caminho do arquivo
path = "/content/drive/My Drive/ggg2.rar"

# Descompacte o arquivo RAR
with rarfile.RarFile(path) as rar:
    rar.extractall(".")

# Leia o arquivo CSV descompactado
data2 = pd.read_csv("GlobalLandTemperaturesByCountry.csv")

# %%
# Obtenha o caminho do arquivo
path = "/content/drive/My Drive/ggg3.rar"

# Descompacte o arquivo RAR
with rarfile.RarFile(path) as rar:
    rar.extractall(".")

# Leia o arquivo CSV descompactado
data3 = pd.read_csv("GlobalLandTemperaturesByMajorCity.csv")

# %%
# Obtenha o caminho do arquivo
path = "/content/drive/My Drive/ggg4.rar"
# Descompacte o arquivo RAR
with rarfile.RarFile(path) as rar:
    rar.extractall(".")
# Leia o arquivo CSV descompactado
data4 = pd.read_csv("GlobalLandTemperaturesByState.csv")

# %%
# Carregue o arquivo
uploaded_file = google.colab.files.upload()
# Out:
#      <input type="file" id="files-a37ec2b9-259e-418f-aa12-11d5896f78bc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a37ec2b9-259e-418f-aa12-11d5896f78bc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import rarfile

# Descompacte o arquivo RAR
with rarfile.RarFile("ggg5.rar") as rar:
    rar.extractall(".")

# Leia o arquivo CSV descompactado
data5 = pd.read_csv("GlobalTemperatures.csv")

# %%
# Monte o Google Drive
google.colab.drive.mount('/content/drive')

# Salve o arquivo no Google Drive
with open('GlobalTemperatures.csv', 'r') as f:
    data5 = f.read()

with open('/content/drive/My Drive/GlobalTemperatures.csv', 'w') as f:
    f.write(data5)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
display(data.head())
display(data2.head())
display(data3.head())
display(data4.head())
display(data5.head())
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 0  1743-11-01               6.068                          1.737  Århus
# 1  1743-12-01                 NaN                            NaN  Århus
# 2  1744-01-01                 NaN                            NaN  Århus
# 3  1744-02-01                 NaN                            NaN  Århus
# 4  1744-03-01                 NaN                            NaN  Århus
#
#    Country Latitude Longitude
# 0  Denmark   57.05N    10.33E
# 1  Denmark   57.05N    10.33E
# 2  Denmark   57.05N    10.33E
# 3  Denmark   57.05N    10.33E
# 4  Denmark   57.05N    10.33E
#            dt  AverageTemperature  AverageTemperatureUncertainty Country
# 0  1743-11-01               4.384                          2.294   Åland
# 1  1743-12-01                 NaN                            NaN   Åland
# 2  1744-01-01                 NaN                            NaN   Åland
# ...

# %%
# Importe a biblioteca google.colab.drive
import google.colab.drive

# Monte o Google Drive
google.colab.drive.mount('/content/drive')

# Salve o arquivo no Google Drive
with open('GlobalLandTemperaturesByCountry.csv', 'r') as f:
    data2 = f.read()

with open('/content/drive/My Drive/GlobalLandTemperaturesByCountry.csv', 'w') as f:
    f.write(data2)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
with open('GlobalLandTemperaturesByState.csv', 'r') as f:
    data4 = f.read()

with open('/content/drive/My Drive/GlobalLandTemperaturesByState.csv', 'w') as f:
    f.write(data4)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
google.colab.drive.mount('/content/drive')
with open('GlobalLandTemperaturesByMajorCity.csv', 'r') as f:
    data3 = f.read()

with open('/content/drive/My Drive/GlobalLandTemperaturesByMajorCity.csv', 'w') as f:
    f.write(data3)
